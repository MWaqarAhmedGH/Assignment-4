# %% [markdown]
# <a href="https://colab.research.google.com/github/MWaqarAhmedGH/Assignment-4/blob/main/02_intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  high_low_game.py

#  ------------------------------------------------------------------------------------------------------------------------------  #
#  Problem Statement:-  High-Low Game
# We want you to gain more experience working with control flow and Booleans in Python. To do this, we are going to have you develop a
# game! The game is called High-Low and the way it's played goes as follows:
# Two numbers are generated from 1 to 100 (inclusive on both ends): one for you and one for a computer, who will be your opponent. You
# can see your number, but not the computer's! You make a guess, saying your number is either higher than or lower than the computer's
# number. If your guess matches the truth (ex. you guess your number is higher, and then your number is actually higher than the
# computer's), you get a point. These steps make up one round of the game. The game is over after all rounds have been played.
# We've provided a sample run below.'
# '
# Welcome to the High-Low Game!
# --------------------------------
# Round 1
# Your number is 8
# Do you think your number is higher or lower than the computer's?: lower
# You were right! The computer's number was 35
# Your score is now 1

# Round 2
# Your number is 88
# Do you think your number is higher or lower than the computer's?: higher
# Aww, that's incorrect. The computer's number was 100
# Your score is now 1

# Round 3
# Your number is 63
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 5
# Your score is now 2

# Round 4
# Your number is 57
# Do you think your number is higher or lower than the computer's?: lower
# Aww, that's incorrect. The computer's number was 57
# Your score is now 2

# Round 5
# Your number is 22
# Do you think your number is higher or lower than the computer's?: lower
# Aww, that's incorrect. The computer's number was 1
# Your score is now 2

# Thanks for playing
#  ------------------------------------------------------------------------------------------------------------------------------  #

import random  # Import random for generating numbers

print("🎮 Welcome to the High-Low Game!")
print("-" * 40)

score = 0  # Keeps track of user's correct guesses
total_rounds = 5  # Number of rounds to play

# Loop through each round
for round_num in range(1, total_rounds + 1):
    print(f"Round {round_num}")

    user_number = random.randint(1, 100)       # Your random number
    computer_number = random.randint(1, 100)   # Computer's secret number

    print(f"Your number is {user_number}")

    # Take user's guess and clean the input
    guess = input("Do you think your number is higher or lower than the computer's? ").lower().strip()

    # Check if the user's guess is correct (with flexible options)
    if (guess in ["higher", "high", "h"] and user_number > computer_number) or \
       (guess in ["lower", "low", "l"] and user_number < computer_number):
        print(f"✅ You were right! The computer's number was {computer_number}")
        score += 1  # Add to score
    else:
        print(f"❌ Aww, that's incorrect. The computer's number was {computer_number}")

    print(f"Your score is now {score}\n")

# Show final result
print("🎉 Game Over! Thanks for playing.")
print(f"👉 Final Score: {score} out of {total_rounds}")
# Out:
# 🎮 Welcome to the High-Low Game!
# ----------------------------------------
# Round 1
# Your number is 86
# Do you think your number is higher or lower than the computer's? h
# ✅ You were right! The computer's number was 53
# Your score is now 1
#
# Round 2
# Your number is 81
# Do you think your number is higher or lower than the computer's? h
# ✅ You were right! The computer's number was 51
# Your score is now 2
#
# Round 3
# Your number is 83
# Do you think your number is higher or lower than the computer's? h
# ✅ You were right! The computer's number was 58
# Your score is now 3
#
# Round 4
# Your number is 78
# Do you think your number is higher or lower than the computer's? h
# ❌ Aww, that's incorrect. The computer's number was 91
# Your score is now 3
#
# Round 5
# Your number is 23
# Do you think your number is higher or lower than the computer's? h
# ❌ Aww, that's incorrect. The computer's number was 94
# Your score is now 3
#
# 🎉 Game Over! Thanks for playing.
# ...

# %%
#  Index_Game.py

#  ------------------------------------------------------------------------------------------------------------------------------  #
#  Problem # 2: Index Game
#  As a warmup, read this code and play the game a few times. Use this mental model of the list:
#  Objective:
#  Create a Python program that helps you practice accessing and manipulating elements in a list. This exercise will help you get comfortable
#  with indexing, slicing, and modifying list elements.
#  Instructions: Initialize a List: Create a list with at least 5 different elements. They can be numbers, strings, or a mix of both.
#  Accessing Elements: Write a function that: Accepts a list and an index as inputs. Returns the element at the specified index.
#  If the index is out of range, return an appropriate message. Modifying Elements: Write a function that: Accepts a list, an index,
#  and a new value as inputs. Replaces the element at the specified index with the new value. If the index is out of range, return an
#  appropriate message. Slicing the List: Write a function that: Accepts a list, a start index, and an end index as inputs.
#  Returns a new list containing the elements from the start index up to (but not including) the end index.
#  Handles cases where the indices are out of range. Game Interaction: Create a simple text-based game that:
#  Prompts the user to select an operation (access, modify, slice). Asks for the necessary inputs (index, new value, etc.).
#  Displays the result and the updated list.
#  ------------------------------------------------------------------------------------------------------------------------------  #

# Function to access an element at a specific index
def access_element(my_list, index):
    # Check if index is in valid range
    if 0 <= index < len(my_list):
        return my_list[index]
    else:
        return "Index out of range"

# Function to modify an element at a specific index
def modify_element(my_list, index, new_value):
    if 0 <= index < len(my_list):
        my_list[index] = new_value
        return f"Updated list: {my_list}"
    else:
        return "Index out of range"

# Function to slice a list
def slice_list(my_list, start, end):
    # Python slicing handles out of range gracefully
    return my_list[start:end]

# Game starts here
def list_game():
    # Create an initial list with mix of elements
    my_list = ['red', 'blue', 42, 'green', 99]

    while True:
        print("\nChoose an operation: access / modify / slice / exit")
        choice = input("Enter your choice: ").lower()

        if choice == "access":
            idx = int(input("Enter index to access: "))
            print("Result:", access_element(my_list, idx))

        elif choice == "modify":
            idx = int(input("Enter index to modify: "))
            new_val = input("Enter new value: ")
            print(modify_element(my_list, idx, new_val))

        elif choice == "slice":
            start = int(input("Enter start index: "))
            end = int(input("Enter end index: "))
            print("Sliced list:", slice_list(my_list, start, end))

        elif choice == "exit":
            print("Thanks for playing!")
            break

        else:
            print("Invalid choice. Try again!")

list_game()
# Out:
# Choose an operation: access / modify / slice / exit
# Enter your choice: access
# Enter index to access: 0
# Result: red
#
# Choose an operation: access / modify / slice / exit
# Enter your choice: exit
# Thanks for playing!

# %%
#  List_Practice.py

#  ------------------------------------------------------------------------------------------------------------------------------  #
#  Problem # 1: List Practice
#  Now practice writing code with lists! Implement the functionality described in the comments below.
#  def main(): # Create a list called fruit_list that contains the following fruits: 'apple', 'banana', 'orange', 'grape', 'pineapple'.
#  Print the length of the list. # Add 'mango' at the end of the list. # Print the updated list.
#  ------------------------------------------------------------------------------------------------------------------------------  #

def main():
    # Create a list with initial fruits
    fruit_list = ['apple', 'banana', 'orange', 'grape', 'pineapple']

    # Print the number of elements in the list
    print("Length of fruit list:", len(fruit_list))

    # Add 'mango' to the end of the list
    fruit_list.append('mango')

    # Print the updated fruit list
    print("Updated fruit list:", fruit_list)

    # Print the updated number of elements in the list
    print("Length of fruit list:", len(fruit_list))


main()
# Out:
# Length of fruit list: 5
# Updated fruit list: ['apple', 'banana', 'orange', 'grape', 'pineapple', 'mango']
# Length of fruit list: 6

# %%
#  Planetary_Weight_Calculator.py

#  ------------------------------------------------------------------------------------------------------------------------------  #
#  Problem: Planetary Weight Calculator
# Milestone # 1: Mars Weight
# A few years ago, NASA made history with the first controlled flight on another planet. Its latest Mars Rover, Perseverance, has onboard
# a 50cm high helicopter called Ingenuity. Ingenuity made its third flight, during which it flew faster and further than it had on any of
# its test flights on Earth. Interestingly, Ingenuity uses Python for some of its flight modeling software!
# Ingenuity on the surface of Mars (source: NASA)
# When programming Ingenuity, one of the things that NASA engineers need to account for is the fact that due to the weaker gravity on
# Mars, an Earthling's weight on Mars is 37.8% of their weight on Earth. Write a Python program that prompts an Earthling to enter their
# weight on Earth and prints their calculated weight on Mars.
# The output should be rounded to two decimal places when necessary. Python has a round function which can help you with this. You pass
# in the value to be rounded and the number of decimal places to use. In the example below, the number 3.1415926 is rounded to 2 decimal
# places which is 3.14.

# x = 3.1415926
# rounded_x = round(x, 2) # rounds x to 2 decimal places
# print(rounded_x)

# # This would print out out 3.14
# x = 2.71828
# rounded_x = round(x, 4)
# print(rounded_x)
# # This would print out 2.7183
# x = 3
# rounded_x = round(x, 4)
# print(rounded_x)
# # This would print 3
# # Note that the round function does not add on decimal places that are not there already
# Sample Run
# $ python marsweight.py
# Enter a weight on Earth: 120
# The equivalent on Mars: 45.36
# Sample Run
# $ python marsweight.py
# Enter a weight on Earth: 186
# The equivalent on Mars: 70.31
#  ------------------------------------------------------------------------------------------------------------------------------  #

# Ask the user to input their weight on Earth
earth_weight = float(input("Enter a weight on Earth: "))

# Calculate Mars weight using Mars gravity factor (37.8% of Earth's gravity)
mars_weight = earth_weight * 0.378

# Round the Mars weight to 2 decimal places
mars_weight_rounded = round(mars_weight, 2)

# Print the final result
print("The equivalent on Mars:", mars_weight_rounded)
# Out:
# Enter a weight on Earth: 55
# The equivalent on Mars: 20.79
